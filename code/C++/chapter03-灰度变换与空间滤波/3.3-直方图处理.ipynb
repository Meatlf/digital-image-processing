# %% [markdown]
# # 3.3-直方图处理
# ## 参考资料
# [1] [python+OpenCV 彩色直方图均衡化](https://www.jianshu.om/p/9a9000d226b6)
# [2] [openCV—Python(8)—— 图像直方图及其直方图均衡化](https://blog.csdn.net/jnulzl/article/details/47171549)

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

# %%
img = cv2.imread('../../data/moon.png',0)
plt.imshow(img, 'gray')

# %%
#图像直方图
hist = cv2.calcHist([img],[0],None,[256],[0,256])

plt.figure()#新建一个图像
plt.title("Grayscale Histogram")#图像的标题
plt.xlabel("Bins")#X轴标签
plt.ylabel("# of Pixels")#Y轴标签
plt.plot(hist)#画图
plt.xlim([0,256])#设置x坐标轴范围
plt.show()#显示图像

# %%
eq = cv2.equalizeHist(img)
plt.imshow(eq, 'gray')

# %%
#图像直方图
hist = cv2.calcHist([eq2],[0],None,[256],[0,256])

plt.figure()#新建一个图像
plt.title("Grayscale Histogram")#图像的标题
plt.xlabel("Bins")#X轴标签
plt.ylabel("# of Pixels")#Y轴标签
plt.plot(hist)#画图
plt.xlim([0,256])#设置x坐标轴范围
plt.show()#显示图像

# %% [markdown]
# 二次图像均衡化,图像不变,可证明. P.S 书本习题3.7

# %%
eq2 = cv2.equalizeHist(eq)
plt.imshow(eq2, 'gray')

# %%
#图像直方图
hist = cv2.calcHist([eq2],[0],None,[256],[0,256])

plt.figure()#新建一个图像
plt.title("Grayscale Histogram")#图像的标题
plt.xlabel("Bins")#X轴标签
plt.ylabel("# of Pixels")#Y轴标签
plt.plot(hist)#画图
plt.xlim([0,256])#设置x坐标轴范围
plt.show()#显示图像
