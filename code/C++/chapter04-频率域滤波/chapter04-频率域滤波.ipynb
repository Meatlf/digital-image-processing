# %% [markdown]
# # chapter04-频率了
# ## 参考资料
# [1] [机器视觉 OpenCV—python 数据增强](https://blog.csdn.net/wsp_1138886114/article/details/83028948)

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

# %%
img = cv2.imread('../../data/moon.png',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
# Out:
# /home/ttz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
rows, cols = img.shape
crow,ccol = rows/2 , cols/2
fshift[crow-30:crow+30, ccol-30:ccol+30] = 0
f_ishift = np.fft.ifftshift(fshift)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)
plt.subplot(131),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img_back, cmap = 'gray')
plt.title('Image after HPF'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5518ee36d9ca> in <module>
#       1 rows, cols = img.shape
#       2 crow,ccol = rows/2 , cols/2
# ----> 3 fshift[crow-30:crow+30, ccol-30:ccol+30] = 0
#       4 f_ishift = np.fft.ifftshift(fshift)
#       5 img_back = np.fft.ifft2(f_ishift)
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
gamma = 5
gammaedImg = gamma_transform(img, gamma)
plt.imshow(gammaedImg, 'gray')
